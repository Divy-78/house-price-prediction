# %%
import pandas as pd

# %%
import os
print(os.listdir("../data"))
# Out:
# ['House Price Prediction Dataset (1).csv']

# %%
df=pd.read_csv("../data/House Price Prediction Dataset (1).csv")
df.head()
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 1   2  4272         5          4       3       1958  Downtown  Excellent
# 2   3  3592         2          2       3       1938  Downtown       Good
# 3   4   966         4          2       2       1902  Suburban       Fair
# 4   5  4926         1          4       2       1975  Downtown       Fair
#
#   Garage   Price
# 0     No  149919
# 1     No  424998
# 2     No  266746
# 3    Yes  244020
# 4    Yes  636056

# %%
print(df.shape)
# Out:
# (2000, 10)

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Id         2000 non-null   int64
#  1   Area       2000 non-null   int64
#  2   Bedrooms   2000 non-null   int64
#  3   Bathrooms  2000 non-null   int64
#  4   Floors     2000 non-null   int64
#  5   YearBuilt  2000 non-null   int64
#  6   Location   2000 non-null   str
#  7   Condition  2000 non-null   str
#  8   Garage     2000 non-null   str
#  9   Price      2000 non-null   int64
# dtypes: int64(7), str(3)
# memory usage: 184.3 KB
# None

# %%
x=df.drop("Price",axis=1)
x=x.drop("Id",axis=1)
x=x.drop("YearBuilt",axis=1)
x=x.drop("Location",axis=1)
y=df["Price"]
print(x.head())
print(y.head())
# Out:
#    Area  Bedrooms  Bathrooms  Floors  Condition Garage
# 0  1360         5          4       3  Excellent     No
# 1  4272         5          4       3  Excellent     No
# 2  3592         2          2       3       Good     No
# 3   966         4          2       2       Fair    Yes
# 4  4926         1          4       2       Fair    Yes
# 0    149919
# 1    424998
# 2    266746
# 3    244020
# 4    636056
# Name: Price, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
x["Condition"]=le.fit_transform(x["Condition"])
x["Garage"]=le.fit_transform(x["Garage"])
print(x.head())
print(x.columns)
# Out:
#    Area  Bedrooms  Bathrooms  Floors  Condition  Garage
# 0  1360         5          4       3          0       0
# 1  4272         5          4       3          0       0
# 2  3592         2          2       3          2       0
# 3   966         4          2       2          1       1
# 4  4926         1          4       2          1       1
# Index(['Area', 'Bedrooms', 'Bathrooms', 'Floors', 'Condition', 'Garage'], dtype='str')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)            
print(y_test.shape)
# Out:
# (1600, 6)
# (400, 6)
# (1600,)
# (400,)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
import pickle

with open("model.pkl", "wb") as file:
    pickle.dump(model, file)

# %%
predictions = model.predict(x_test)
print(predictions[:5])
# Out:
# [522027.03079842 550437.8837684  500992.20338563 552525.32345311
#  566062.53710435]

# %%
from sklearn.metrics import mean_absolute_error, r2_score 
mae = mean_absolute_error(y_test, predictions)
r2 = r2_score(y_test, predictions)
print("Mean Absolute Error:", mae)
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 244360.66071051836
# R-squared: -0.011080036612732158
